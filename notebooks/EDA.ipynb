# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\deyar\OneDrive\Desktop\InsurencepPricePrediction\notebooks\data\insurance.csv')

# %%
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
import seaborn as sn

# %%
import matplotlib.pyplot as pl

# %%
pl.figure(figsize=(15,4))
pl.subplot(1,2,1)
data["sex"].value_counts().plot(kind="pie",autopct="%.2f%%",
                                    )
pl.subplot(1,2,2)
a=sn.countplot(data=data,x="sex",color="k")
for i in a.containers:
  a.bar_label(i)
pl.show()

# %%
pl.figure(figsize=(15,4))
pl.subplot(1,2,1)
data["smoker"].value_counts().plot(kind="pie",autopct="%.2f%%",
                                    )
pl.subplot(1,2,2)
a=sn.countplot(data=data,x="smoker",color="g")
for i in a.containers:
  a.bar_label(i)
pl.show()

# %%
pl.figure(figsize=(15,4))
pl.subplot(1,2,1)
data["region"].value_counts().plot(kind="pie",autopct="%.2f%%",
                                    )
pl.subplot(1,2,2)
a=sn.countplot(data=data,x="region",color="b")
for i in a.containers:
  a.bar_label(i)
pl.show()

# %%
pl.figure(figsize=(15,4))
pl.subplot(1,2,1)
data["children"].value_counts().plot(kind="pie",autopct="%.2f%%",
                                   explode=[0,0,0,.2,.1,.5] )
pl.subplot(1,2,2)
a=sn.countplot(data=data,x="children",color="r")
for i in a.containers:
  a.bar_label(i)
pl.show()

# %%
pl.figure(figsize=(20,6))
sn.regplot(x='bmi', y='expenses', data = data,color='g')
pl.figure(figsize=(20,6))
sn.regplot(x='bmi', y='expenses', data = data,scatter=False,ci=None,order=2,color='r')
pl.show()

# %% [markdown]
# expenses is increasing with bmi

# %%
pl.figure(figsize=(20,6))
sn.kdeplot(data=data,x='expenses',hue='sex')
pl.show()

# %%
pl.figure(figsize=(20,4))
sn.kdeplot(data=data,x='expenses',hue='smoker')
pl.show()

# %% [markdown]
# expenses is very high for smoker

# %%
pl.figure(figsize=(15,4))
sn.lmplot(x='bmi', y='expenses', data = data,hue='sex',col='sex',palette='husl')
pl.figure(figsize=(20,6))
sn.lmplot(x='bmi', y='expenses', data = data,scatter=False,ci=None,order=2,hue='sex',col='sex',palette='husl')
pl.show()

# %% [markdown]
# where sex=male there after 42 bmi, expenses have droped

# %%
data.head(2)
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55

# %%
pl.figure(figsize=(15,4))
sn.regplot(x='bmi', y='expenses', data = data,color='m')
pl.figure(figsize=(15,4))
sn.regplot(x='age', y='expenses', data = data,scatter=False,ci=None,order=2,color='k')
pl.show()

# %% [markdown]
# with the age expenses is increasing

# %%
pl.figure(figsize=(15,6))
sn.kdeplot(data=data,x='expenses',hue='children',palette='dark')
pl.show()

# %% [markdown]
# who has zero children ,their expenses are high

# %%
data.head(2)
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55

# %%
pl.figure(figsize=(15,6))
a=sn.barplot(data=data,x='region',y='expenses',ci=False,palette='husl')
for i in a.containers:
  a.bar_label(i)

# %% [markdown]
# southeast's expenses are high

# %%
pl.figure(figsize=(15,6))
a=sn.barplot(data=data,x='region',y='expenses',ci=False,palette='husl',hue='sex')
for i in a.containers:
  a.bar_label(i)

# %% [markdown]
# male's expenses are high but in northwest both are appx. same.

# %%
pl.figure(figsize=(15,6))
a=sn.countplot(data=data,x='region',palette='hls',hue='smoker')
for i in a.containers:
  a.bar_label(i)

# %% [markdown]
# no of smokers are high in southeast

# %%
pip install ydata-profiling
# Out:
# ...
#   Using cached visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# ...
# Using cached visions-0.7.6-py3-none-any.whl (104 kB)
# ...
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.

# %%
from ydata_profiling import ProfileReport

# %%
data=pd.read_csv(r'C:\Users\deyar\OneDrive\Desktop\InsurencepPricePrediction\notebooks\data\insurance.csv')

# %%
profile=ProfileReport(data,explorative=True,dark_mode=True)

# %%
profile.to_file('my_report.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<?, ?it/s]
